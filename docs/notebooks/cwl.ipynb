# %%
# !pip install planemo
# Out:
# You are using pip version 6.1.1, however version 7.1.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ...

# %%
# !planemo project_init --template cwl_draft2_spec
# Out:
# wget -q --recursive -O - 'https://codeload.github.com/galaxyproject/planemo/tar.gz/master' | tar  -C /tmp/tmpnesC3S -zxf - --strip-components=2
# ls '/tmp/tmpnesC3S'
# appliance.rst
# bioblend.py
# bootstrap_history.py
# bwa
# categories.py
# cli.py
# commands
# commands.rst
# commands_to_rst.py
# commit_version.py
# conduct.rst
# config.py
# configuration.rst
# conf.py
# contributing.rst
# cwl
# cwl2script
# cwl_draft2_spec
# cwl-runner
# data
# demo
# developing.rst
# galaxy
# galaxy_config.py
# galaxy_run.py
# galaxy_serve.py
# galaxy_test
# github_util.py
# git.py
# glob.py
# history.rst
# images
# index.rst
# __init__.py
# installation.rst
# io.py
# linters
# lint.py
# make.bat
# Makefile
# modules.rst
# network_util.py
# new_version.py
# notebooks
# options.py
# organization.rst
# other_docs.rst
# package_bwa_0_7_7
# package_samtools_0.1.16
# package_seqtk_1_0_r75
# planemo.commands.rst
# planemo.cwl.rst
# planemo_ext.cwl2script.rst
# ...

# %%
ls
# Out:
# add-lines-wf.cwl*      count-lines8-wf.cwl*  scatter-job2.json
# basics.ipynb           count-lines9-wf.cwl*  scatter-wf1.cwl
# binding-test.cwl*      cwl.ipynb             scatter-wf2.cwl
# bwa-mem-job.json       echo-tool.cwl         scatter-wf3.cwl
# bwa-mem-tool.cwl*      empty.json            scatter-wf4.cwl
# cat1-tool.cwl*         env-job.json          search.cwl
# cat2-tool.cwl*         env-tool1.cwl         search-job.json
# cat3-tool.cwl*         env-tool2.cwl         search.py*
# cat4-tool.cwl*         env-wf1.cwl           seqtk_seq.xml
# cat5-tool.cwl*         env-wf2.cwl           sorttool.cwl
# cat-job.json           hello.txt             template-tool.cwl*
# cat-n-job.json         index.py*             test-data/
# count-lines1-wf.cwl*   node-engine.cwl       tmap-job.json
# count-lines2-wf.cwl*   number.txt            tmap-tool.cwl*
# count-lines3-job.json  parseInt-job.json     underscore.js
# count-lines3-wf.cwl*   parseInt-tool.cwl*    wc2-tool.cwl*
# ...

# %%
# !planemo serve --cwl cat3-tool.cwl
# Out:
# Starting galaxy with command [/home/john/workspace/galaxy/run.sh --server-name 'planemo18130' --reload]
# Activating virtualenv at /home/john/workspace/galaxy/.venv
# Ignoring indexes: https://pypi.python.org/simple
# /home/john/workspace/galaxy/.venv/local/lib/python2.7/site-packages/pip/_vendor/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# Requirement already up-to-date: pip in ./.venv/lib/python2.7/site-packages
# ...
# Activating virtualenv at /home/john/workspace/galaxy/.venv
# Starting subprocess with file monitor
# ...

# %%
# !planemo cwl_run cat3-tool.cwl cat-job.json
# Out:
# Starting galaxy with command [/home/john/workspace/galaxy/run.sh --daemon --wait]
# Activating virtualenv at /home/john/workspace/galaxy/.venv
# Ignoring indexes: https://pypi.python.org/simple
# /home/john/workspace/galaxy/.venv/local/lib/python2.7/site-packages/pip/_vendor/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# Requirement already up-to-date: pip in ./.venv/lib/python2.7/site-packages
# ...
# Activating virtualenv at /home/john/workspace/galaxy/.venv
# Entering daemon mode
# .........
# {u'stdin': None, u'command_line': [u'cat', u'/tmp/tmptEYGQR/files/000/dataset_1.dat'], u'stdout': u'output.txt'}
